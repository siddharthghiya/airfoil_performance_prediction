# %%
import matplotlib.pyplot as plt
import numpy as np
output = np.load('Foil_CNN_Prediction_99.npy')
print(output.shape)
plt.scatter(output[:,3],output[:,5])
plt.xlabel('True Value')
plt.ylabel('Predicted Value')
plt.show()
# Out:
# (90, 50, 6)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-52b0c1af9c08> in <module>()
#       3 output = np.load('Foil_CNN_Prediction_99.npy')
#       4 print(output.shape)
# ----> 5 plt.scatter(output[:,3],output[:,5])
#       6 plt.xlabel('True Value')
#       7 plt.ylabel('Predicted Value')
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3473                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3474                          linewidths=linewidths, verts=verts,
# -> 3475                          edgecolors=edgecolors, data=data, **kwargs)
#    3476     finally:
#    3477         ax._hold = washold
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
output = np.load('FCNN_10.npy')
print(output.shape)
plt.scatter(output[:,3],output[:,5])
plt.xlabel('True Value')
plt.ylabel('Predicted Value')
plt.show()
# Out:
# (4500, 6)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d9e778170980> in <module>()
#       6 plt.xlabel('True Value')
#       7 plt.ylabel('Predicted Value')
# ----> 8 plt.show()
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...

# %%
output=output.astype(str)
np.savetxt("Foil_FC_prediction.csv", output, delimiter=",", fmt='%s')
